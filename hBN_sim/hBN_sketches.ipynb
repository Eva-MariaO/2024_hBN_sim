# %%
import numpy as np
import matplotlib.pyplot as plt
import abtem
import ase


from datetime import datetime

# %%
#setting configuration (?)
abtem.config.set({"device": "cpu", "fft": "fftw"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-ffa53155cac6> in <module>
#       1 #setting configuration (?)
# ----> 2 abtem.config.set({"device": "cpu", "fft": "fftw"})
#
# AttributeError: module 'abtem' has no attribute 'config'

# %% [markdown]
# #! später noch:
# SETTINGS -> GPU VERWENDEN!! mit remote connection
#
# - struktur vergrößern (derzeit wieder 10x7 statt 20x20)
# - evtl. number configs
# - grid_scan: start/ende erweitern
#
# - angular spread bei probe bzw. ctf! [ansprechbar über probe.ctf.angular_spread]

# %%
# Parameters and Settings
vacancy_atom = 'B' # enter 'N' for replacement of N-atom, or 'B' for replacement of B-atom
defect_atom_symbol = 'O' # symbol of impurity atom(s)
defect_type = 'double' #'single'/'double' for calculating potential etc with single/double defect
lattice_constant = 2.504 # lattice constant for hBN, https://www.sciencedirect.com/science/article/abs/pii/S0025540815300088

#probe #!
energy_probe = 60e3
defocus = 0 # 0 or f.e.: 'scherzer'
semiangle_cutoff = 30 # maybe set to ctf crossover_angle, see below -> probe -> ctf? #!

Cs = -10e-6*1e10 #spherical aberration; 10 micrometers
astig = 10 #aberration C12, ~few nanometers
coma = 1000 # aberration C21, ~few hundred nanometers
focal_spread = 10.0
angular_spread = 0.0

#path
now = datetime.now()
path = (f'hBN_{defect_type}_vacany{vacancy_atom}_filledwith{defect_atom_symbol}_energy{int(energy_probe)}_defocus{defocus}_Cs{int(Cs)}_focal{int(focal_spread)}_ang{int(angular_spread)}_Date{now.year}{now.month}{now.day}_{now.hour}{now.minute}{now.second}')
print(path)
# Out:
# hBN_double_vacanyB_filledwithO_energy60000_defocus0_Cs-100000_focal1_ang1_Date2024723_191215

# %% [markdown]
# # Atomic structure

# %%
#create hBN cell
hBN_cell_0 = ase.build.graphene(formula='BN', a=lattice_constant, thickness=0.0, size=(1, 1, 1), vacuum=2)

#orthogonalize cell and create structure
hBN_orth_0, trafo_0 = abtem.orthogonalize_cell(hBN_cell_0, return_transform=True)
hBN_0 = hBN_orth_0*(3, 2, 1)

abtem.show_atoms(hBN_0, legend=True, numbering=True, merge=False, figsize=(4,4))

plt.tight_layout()

# %% [markdown]
# ### get infos about structure

# %%
abtem.atoms.pretty_print_transform(trafo_0)
# Out:
# Euler angles (degrees): 	 x = 0.000, 	 y = -0.000, 	 z = 0.000
# Normal strains (percent): 	 x = 0.000, 	 y = 0.000, 	 z = 0.000
# Shear strains (percent): 	 xy = 0.000, 	 xz = 0.000, 	 xz = 0.000

# %%
b_atom = hBN_0[12]
b_atom
# Out:
# Atom('B', [2.504, 4.337055222152468, 2.0], index=12)

# %%
n_atom = hBN_0[13]
print(f'Distance B-N: {hBN_0.get_distance(12, 13):.3f} Å')
print(f'Distance B-B: {hBN_0.get_distance(0, 3):.3f} Å')
#does not align with value 1.446 A° of: https://www.researchgate.net/figure/Schematic-of-hexagonal-boron-nitride-h-BN-structure_fig1_258712674
# Out:
# Distance B-N: 1.446 Å
# Distance B-B: 2.504 Å

# %%
#get cell parameters
print(hBN_cell_0.cell.cellpar())
print(hBN_0.cell.cellpar())
# Out:
# [  2.504   2.504   4.     90.     90.    120.   ]
# [ 7.512       8.67411044  4.         90.         90.         90.        ]

# %% [markdown]
# ### Structure & Manipulation

# %%
#create actual structure for further usage
#create hBN cell
hBN_cell = ase.build.graphene(formula='BN', a=lattice_constant, thickness=0.0, size=(1, 1, 1), vacuum=2)

#orthogonalize cell and create structure
hBN_orth = abtem.orthogonalize_cell(hBN_cell)
hBN = hBN_orth*(10, 7, 1) #!

# %%
#plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
abtem.show_atoms(hBN, ax=ax1, title='center')
abtem.show_atoms(hBN, legend=True, figsize=(4,4), ax=ax2, title='complete')

x_center = max(hBN.positions[:, 0])/2
y_center = max(hBN.positions[:, 1])/2

#ax1.set_xlim(x_center - 2*lattice_constant, x_center + 2*lattice_constant)
#ax1.set_ylim(y_center - 2*lattice_constant, y_center + 2*lattice_constant)
plt.tight_layout()

# %%
#find atoms located in the center
mask_center_position_x = ((hBN.positions[:,0] < x_center + lattice_constant)*
                          (hBN.positions[:,0] > x_center - lattice_constant))
mask_center_position_y = ((hBN.positions[:,1] < y_center + lattice_constant)*
                          (hBN.positions[:,1] > y_center - lattice_constant))
mask_center = mask_center_position_x * mask_center_position_y

center_indices = (np.asarray(np.where(mask_center == True)))[0]
center_indices.shape
# Out:
# (8,)

# %%
#insert impurity atoms 
hBN_manipulated_0 = hBN.copy()
hBN_manipulated_0.symbols[mask_center] = 'C'

#plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
abtem.show_atoms(hBN_manipulated_0, ax=ax1, title='center')
abtem.show_atoms(hBN_manipulated_0, legend=True, figsize=(4,4), ax=ax2, title='complete structure')

ax1.set_xlim(x_center - 2*lattice_constant, x_center + 2*lattice_constant)
ax1.set_ylim(y_center - 2*lattice_constant, y_center + 2*lattice_constant)
plt.tight_layout()

# %% [markdown]
# ### Single and Double Defects

# %%
#SINGLE: find index values in the middle of center index array to adress one (or two) specific atom(s)
ind = int(len(center_indices)/2 - 1) #center_indices.shape = (1,8);
ind_random = center_indices[ind]

#check if chosen atom is wanted single defect type and/or (re-)assign
if hBN.symbols[ind_random] == vacancy_atom:
    ind_single = ind_random
else:
    ind_single = center_indices[ind + 2]
    # +2 because Atoms are saved in the structure [... N N B B N N B...]

#for DOUBLE: make sure, the two atoms are neighbours
#find distance of next neighbours
nnd = round(hBN.get_distance(1, 3),4)

for index in center_indices:
    index_dist = round(hBN.get_distance(ind_single, index),4)
    if index_dist == nnd:
        #found next neighbour -> assign second index
        ind_double = [ind_single, index]
        break
    else:
        pass
    
print(f'Center indices: {center_indices}')
print(f'Chosen index single: {ind_single}')
print(f'Chosen index double: {ind_double}')
# Out:
# Center indices: [124 125 126 127 152 153 154 155]
# Chosen index single: 127
# Chosen index double: [127, 125]

# %%
#insert impurity atoms - introducing single and double defects
hBN_single = hBN.copy()
hBN_double = hBN.copy()

hBN_single.symbols[ind_single] = defect_atom_symbol
hBN_double.symbols[ind_double] = defect_atom_symbol

#plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
abtem.show_atoms(hBN_single, ax=ax1, title='single defect')
abtem.show_atoms(hBN_double, legend=True, figsize=(4,4), ax=ax2, title='double defect')

for ax in (ax1, ax2):
    ax.set_xlim(x_center - 2*lattice_constant, x_center + 2*lattice_constant)
    ax.set_ylim(y_center - 2*lattice_constant, y_center + 2*lattice_constant)
    
plt.tight_layout()

# %% [markdown]
# # Potential

# %%
#RUN BEFORE CALCULATING POTENTIAL
if defect_type == 'double':
    hBN_manipulated = hBN_double
elif defect_type == 'single':
    hBN_manipulated = hBN_single
else:
    raise KeyboardInterrupt

# %%
#implement frozen phonons (average of random offset-snapshots)
frozen_phonons = abtem.FrozenPhonons(hBN_manipulated, num_configs=10, sigmas=0.1) #! num_configs

# %%
frozen_it = iter(frozen_phonons)
atoms_configuration_list = [None] * frozen_phonons.shape[0]

for config_i in range(frozen_phonons.shape[0]):
    atoms_configuration_list[config_i] = next(frozen_it)

indizes = (0,1,2)

#plot
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(11, 4))
abtem.show_atoms(atoms_configuration_list[indizes[0]], scale=0.3, ax=ax1, title="config1")
abtem.show_atoms(atoms_configuration_list[indizes[1]], scale=0.3, ax=ax2, title="config2")
abtem.show_atoms(atoms_configuration_list[indizes[2]], scale=0.3, ax=ax3, title="config3")

ax1.set_xlim(9,14)
ax1.set_ylim(13,18)

plt.tight_layout()

# %%
#create potential (sampling = physical extent/ gridpoints), slice thickness not usefull - no layers
potential = abtem.Potential(frozen_phonons, sampling=0.05)
potential.shape
# Out:
# (10, 4, 501, 608)

# %%
potential.axes_metadata
# Out:
# type               label           coordinates
# -----------------  --------------  -------------------
# FrozenPhononsAxis  Frozen phonons  -
# ThicknessAxis      z [Å]           1.00 2.00 ... 4.00
# RealSpaceAxis      x [Å]           0.00 0.05 ... 24.99
# RealSpaceAxis      y [Å]           0.00 0.05 ... 30.31

# %%
potential.build().compute()
# Out:
# [########################################] | 100% Completed | 710.87 ms

# %% [markdown]
# # Probe

# %%
#consider partial temporal coherence (due to energy spread of probe) by building gaussian distributed defocus series
focal_spread = focal_spread
defocus_distribution = abtem.distributions.gaussian(center=0.0, standard_deviation=focal_spread, num_samples=11,
                                                    sampling_limit=2, ensemble_mean=False,)
#condider partial spacial coherence (due to source size)
#angular_spread = angular_spread

#create probe and insert parameters for abberations (ctf)
aberration_coefficients = {'C10': defocus_distribution, 'C30': Cs, 'C12': astig, 'C21': coma}

# %%
probe = abtem.Probe(energy=energy_probe, semiangle_cutoff=semiangle_cutoff, aberrations=aberration_coefficients) #maybe use crossover angle of ctf for semiangle_cutoff? #!
probe.grid.match(potential)
probe.sampling
# Out:
# (0.04998003992015968, 0.04993320157083434)

# %%
#angular_spread lässt sich nicht einstellen
probe.ctf.energy = 1.0
probe.ctf.energy
# Out:
# 60000.0

# %%
ctf_new = probe.ctf.copy()
ctf_new.energy = 1.0
ctf_new.energy

probe.ctf.energy = ctf_new.energy
probe.ctf.energy
# Out:
# 60000.0

# %%
#Contrast Transfer Function -> 
ctf = abtem.CTF(energy=energy_probe, Cs=Cs, defocus=defocus)
crossover_angle = ctf.crossover_angle
print(f'crossover_angle = {ctf.crossover_angle:.3f}')

#test different cutoff angle
probe_test = probe.copy()
probe_test.semiangle_cutoff = crossover_angle

#plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,4))
probe.show(ax=ax1)
probe_test.show(ax=ax2, title='cuttoff at crossover angle')

#for ax in (ax1, ax2):
#    ax.set_xlim(20,30)
#    ax.set_ylim(18,25)
# Out:
# crossover_angle = 41.336
# [########################################] | 100% Completed | 303.90 ms
# [########################################] | 100% Completed | 311.61 ms

# %%
probe.build().compute()
# Out:
# [########################################] | 100% Completed | 309.26 ms

# %% [markdown]
# # Scan & Detect

# %%
#choose Nyquist sampling for potential, probe and scan
sampling = probe.aperture.nyquist_sampling
#potential.sampling = sampling -> doesn't give good results
#probe.grid.match(potential)

print(f'Nyquist sampling: {sampling:.3f} Å/pixel')
# Out:
# Nyquist sampling: 0.406 Å/pixel

# %%
#setup for grid scan
#start & ende später anpassen
gridscan = abtem.GridScan(start=[3.5/10, 4/10], end=[6/10, 6/10], fractional = True,
                     potential=potential, sampling=sampling)
fig, ax = abtem.show_atoms(hBN_manipulated, figsize=(4,4))
gridscan.add_to_plot(ax)

# %%
#setup detectors
flex_an_detector = abtem.FlexibleAnnularDetector(step_size=1, inner=60, outer=200) #stepsize of detector 1 mrad

# %%
#apply scan & detectors
measurements_total = probe.scan(potential, scan=gridscan, detectors=flex_an_detector)

# %% [markdown]
# # Export & Import

# %%
#compute and EXPORT... 
measurements_total.to_zarr(f'../data/RAW_{path}.zarr')

#and/or IMPORT from file
imported_measurements = abtem.from_zarr(f'../data/RAW_{path}.zarr')
#imported_measurements_test = abtem.from_zarr('C:/Users/evama/Desktop/Desktop/Praktikum/hBN/data/hBN_double_vacanyB_filledwithC_energy60000_defocus0_Cs-100000_Date2024717_144033.zarr').compute()
#imported_measurements = abtem.from_zarr('C:/Users/evama/INSERTPATH').compute()
#imported_measurements = abtem.from_zarr('./data/hBN_double_vacanyB_filledwithO_energy60000_defocus0_Cs-100000_Date2024718_172853.zarr').compute()

#update path variable to avoide overwriting
#now = datetime.now()
#path = (f'hBN_{defect_type}_vacany{vacancy_atom}_filledwith{defect_atom_symbol}_energy{int(energy_probe)}_defocus{defocus}_Cs{int(Cs)}_Date{now.year}{now.month}{now.day}_{now.hour}{now.minute}{now.second}')
# Out:
# [                                        ] | 0% Completed | 983.37 ms
# /home/torchuser/anaconda3/envs/evamaria_sim/lib/python3.9/site-packages/numba/np/ufunc/dufunc.py:287: RuntimeWarning: overflow encountered in _abs2
#   return super().__call__(*args, **kws)
# [                                        ] | 0% Completed | 4.19 s
# /home/torchuser/anaconda3/envs/evamaria_sim/lib/python3.9/site-packages/abtem/core/fft.py:94: RuntimeWarning: overflow encountered in multiply
#   array *= kernel
# /home/torchuser/anaconda3/envs/evamaria_sim/lib/python3.9/site-packages/abtem/core/fft.py:94: RuntimeWarning: invalid value encountered in multiply
#   array *= kernel
# [#                                       ] | 3% Completed | 65.54 s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[232], line 2
#       1 #compute and EXPORT...
# ----> 2 measurements_total.to_zarr(f'../data/RAW_{path}.zarr')
#       4 #and/or IMPORT from file
#       5 imported_measurements = abtem.from_zarr(f'../data/RAW_{path}.zarr')
#
# File ~/anaconda3/envs/evamaria_sim/lib/python3.9/site-packages/abtem/array.py:155, in ComputableList.to_zarr(self, url, compute, overwrite, progress_bar, **kwargs)
#     150     return computables
#     152 with _compute_context(
#     153     progress_bar, profiler=False, resource_profiler=False
#     154 ) as (_, profiler, resource_profiler):
# --> 155     output = dask.compute(computables, **kwargs)[0]
#     157 profilers = ()
#     158 if profiler is not None:
#
# File ~/anaconda3/envs/evamaria_sim/lib/python3.9/site-packages/dask/base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/anaconda3/envs/evamaria_sim/lib/python3.9/queue.py:171, in Queue.get(self, block, timeout)
#     169 elif timeout is None:
#     170     while not self._qsize():
# --> 171         self.not_empty.wait()
#     172 elif timeout < 0:
#     173     raise ValueError("'timeout' must be a non-negative number")
#
# File ~/anaconda3/envs/evamaria_sim/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %% [markdown]
# # Postprocessing

# %%
#set parameters for postprocessing
interpolate = 0.05
gauss = 0.3
dose = 1e9

path_final = (f'{path}_interpol{interpolate}_gauss{gauss}_dose{dose}')
print(path_final)

# %%
#assign detectors
#bf_measurement = imported_measurements.integrate_radial(0, probe.semiangle_cutoff)
maadf_measurement = imported_measurements.integrate_radial(60, 200)
haadf_measurement = imported_measurements.integrate_radial(80, 200)

#..and plot
measurements = abtem.stack([maadf_measurement, haadf_measurement], ("MAADF", "HAADF"))
measurements.show(explode=True, figsize=(14, 5), cbar=True,);
# Out:
# [########################################] | 100% Completed | 207.41 ms

# %%
#interpolate to smooth images and apply gaussian filter to consider partial spatial coherence (I think?) #!
#...or additionally add gaussian.source_size, see https://abtem.readthedocs.io/en/latest/user_guide/tutorials/partial_coherence.html#partial-coherence-with-probes
final_measurements = measurements.interpolate(interpolate).gaussian_filter(gauss)

#plot
final_measurements.show(explode=True, figsize=(14, 5), cbar=True,);
# Out:
# [                                        ] | 0% Completed | 49.64 sms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[202], line 6
#       3 final_measurements = measurements.interpolate(0.1).gaussian_filter(0.3)
#       5 #plot
# ----> 6 final_measurements.show(explode=True, figsize=(14, 5), cbar=True,)
#
# File ~/anaconda3/envs/evamaria_sim/lib/python3.9/site-packages/abtem/measurements.py:1227, in _BaseMeasurement2D.show(self, ax, cbar, cmap, vmin, vmax, power, common_color_scale, explode, overlay, figsize, title, units, interact, display, **kwargs)
#    1166 def show(
#    1167     self,
#    1168     ax: Axes = None,
#    (...)
#    1182     **kwargs,
#    1183 ) -> Visualization:
#    1184     """
#    1185     Show the image(s) using matplotlib.
#    1186
#    (...)
#    1224     measurement_visualization_2d : VisualizationImshow
#    1225     """
# -> 1227     visualization = Visualization(
#    1228         measurement=self,
#    1229         ax=ax,
#    1230         common_scale=common_color_scale,
#    1231         figsize=figsize,
#    1232         title=title,
#    1233         aspect=True,
#    1234         share_x=True,
#    1235         share_y=True,
#    1236         explode=explode,
#    1237         overlay=overlay,
#    1238         interactive=not interact and display,
#    1239         value_limits=(vmin, vmax),
#    1240         power=power,
#    1241         cmap=cmap,
#    1242         cbar=cbar,
#    1243         units=units,
#    1244         **kwargs,
#    1245     )
#    1247     if interact:
#    1248         gui = visualization.interact(ImageGUI, display=display)
#
# File ~/anaconda3/envs/evamaria_sim/lib/python3.9/site-packages/abtem/visualize/visualizations.py:169, in Visualization.__init__(self, measurement, ax, artist_type, figsize, aspect, common_scale, value_limits, overlay, explode, share_x, share_y, cbar, interactive, title, xlim, ylim, **kwargs)
#     149 def __init__(
#     150     self,
#     151     measurement,
#    (...)
#     167     **kwargs,
#     168 ):
# --> 169     self._measurement = measurement.to_cpu().compute()
#     171     overlay, explode = _validate_axes_types(
#     172         overlay, explode, len(measurement.ensemble_shape)
#     173     )
#     175     self._overlay = overlay
#
# File ~/anaconda3/envs/evamaria_sim/lib/python3.9/site-packages/abtem/array.py:1014, in ArrayObject.compute(self, progress_bar, profiler, resource_profiler, **kwargs)
#    1011 if not self.is_lazy:
#    1012     return self
# -> 1014 output, profilers = _compute(
#    1015     [self],
#    1016     progress_bar=progress_bar,
#    1017     profiler=profiler,
#    1018     resource_profiler=resource_profiler,
#    1019     **kwargs,
#    1020 )
#    1022 output = output[0]
#    1024 if profilers:
#
# File ~/anaconda3/envs/evamaria_sim/lib/python3.9/site-packages/abtem/array.py:239, in _compute(dask_array_wrappers, progress_bar, profiler, resource_profiler, **kwargs)
#     234         kwargs["threads_per_worker"] = cp.cuda.runtime.getDeviceCount()
#     236 with _compute_context(
#     237     progress_bar, profiler=profiler, resource_profiler=resource_profiler
#     238 ) as (_, profiler, resource_profiler):
# --> 239     arrays = dask.compute(
#     240         [wrapper.array for wrapper in dask_array_wrappers], **kwargs
#     241     )[0]
#     243 for array, wrapper in zip(arrays, dask_array_wrappers):
#     244     wrapper._array = array
#
# File ~/anaconda3/envs/evamaria_sim/lib/python3.9/site-packages/dask/base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/anaconda3/envs/evamaria_sim/lib/python3.9/queue.py:171, in Queue.get(self, block, timeout)
#     169 elif timeout is None:
#     170     while not self._qsize():
# --> 171         self.not_empty.wait()
#     172 elif timeout < 0:
#     173     raise ValueError("'timeout' must be a non-negative number")
#
# File ~/anaconda3/envs/evamaria_sim/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
#noise to account for finite electrone dose -> statistic deviation (see abtem walkthrough -> scan & detect)
#before applying noise tile measurements for better statistics -> maybe unnecessary with larger scanning area
#tiled_measurements = final_measurements.tile((7, 4)).compute()
#noisy_measurements = tiled_measurements.poisson_noise(dose_per_area=1e9, seed=100)

noisy_measurements = final_measurements.poisson_noise(dose_per_area=dose, seed=100)
noisy_measurements.show(explode=True, figsize=(12, 4))

#zoom in
#plt.xlim(0,15)
#plt.ylim(0,15)
# Out:
# [########################################] | 100% Completed | 204.35 ms
# (0.0, 15.0)

# %%
#export
noisy_measurements.to_zarr(f'../data/FINAL_{path_final}.zarr')
#noisy_measurements.to_zarr(f'../data/FINAL2_{path_old}.zarr')
# Out:
# [########################################] | 100% Completed | 209.77 ms
# [[None, None, None]]

# %%
import_new = abtem.from_zarr(f'../data/FINAL_{path_final}.zarr')
import_new.show(explode=True)
# Out:
# [########################################] | 100% Completed | 102.49 ms

# %%
#reassign path variable to avoid overwriting
path_old = path
path_final_old = path_final
time_old = {now.year}{now.month}{now.day}_{now.hour}{now.minute}{now.second}

now = datetime.now()
path = (f'hBN_{defect_type}_vacany{vacancy_atom}_filledwith{defect_atom_symbol}_energy{int(energy_probe)}_defocus{defocus}_Cs{int(Cs)}_focal{int(focal_spread)}_ang{int(angular_spread)}_Date{now.year}{now.month}{now.day}_{now.hour}{now.minute}{now.second}')
path_final = (f'{path}_interpol{interpolate}_gauss{gauss}_dose{dose}')

print(path_old)
print(path)
